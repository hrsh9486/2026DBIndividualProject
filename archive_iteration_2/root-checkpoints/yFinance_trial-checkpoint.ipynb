# %%
import yfinance as yf

# %%
ticker = yf.Ticker("QQQ")

# %%
ticker.info['priceHint']
# Out:
# 2

# %%
ticker.news
# Out:
# [{'id': '237c7d98-97e3-362d-8968-719f8aac5be7',
#   'content': {'id': '237c7d98-97e3-362d-8968-719f8aac5be7',
#    'contentType': 'STORY',
#    'title': 'What Actually Drove IWD Over The Past Year',
#    'description': '',
#    'summary': "The fund's strong return hides a story of extreme concentration, with a few winners pulling the weight for hundreds of others.",
#    'pubDate': '2026-07-03T12:55:34Z',
#    'displayTime': '2026-07-03T12:55:34Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/trefis_142/56c363bffa73f8b8cfa9cd71fae1de1c',
#     'originalWidth': 1280,
#     'originalHeight': 869,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/nmtFbJBZ44Vt9xFgQaOr9w--~B/aD04Njk7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/trefis_142/56c363bffa73f8b8cfa9cd71fae1de1c',
#       'width': 1280,
#       'height': 869,
#       'tag': 'original'},
# ...

# %%
ticker.calendar
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: QQQ"}}}
# {}

# %%
ticker.history(period="1mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-06-03 00:00:00-04:00  746.489639  747.828195  740.196567  743.393066
# 2026-06-04 00:00:00-04:00  734.672624  742.683839  731.815778  739.796997
# 2026-06-05 00:00:00-04:00  729.258567  730.886782  703.546833  704.286011
# 2026-06-08 00:00:00-04:00  717.022016  722.236317  712.287229  715.283936
# 2026-06-09 00:00:00-04:00  722.186311  724.863361  685.616515  707.052979
# 2026-06-10 00:00:00-04:00  700.889750  710.499246  692.169352  692.928528
# 2026-06-11 00:00:00-04:00  698.522320  717.581391  694.237051  716.332764
# 2026-06-12 00:00:00-04:00  716.822210  723.215209  710.499203  720.548157
# 2026-06-15 00:00:00-04:00  737.289741  743.942464  736.570560  743.183289
# 2026-06-16 00:00:00-04:00  741.435190  743.402998  728.839048  729.058777
# 2026-06-17 00:00:00-04:00  734.382931  734.872383  720.058646  721.716858
# 2026-06-18 00:00:00-04:00  736.390778  741.005702  731.705924  739.807007
# ...

# %% [raw]
# ticker.history(period="1mo")

# %%
ticker.history(period="1y")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-07-03 00:00:00-04:00  550.528548  554.529299  550.528548  553.553955
# 2025-07-07 00:00:00-04:00  550.866943  551.683020  546.945825  549.384094
# 2025-07-08 00:00:00-04:00  550.727559  551.354544  548.458458  549.692566
# 2025-07-09 00:00:00-04:00  551.822327  554.957253  550.448936  553.583862
# 2025-07-10 00:00:00-04:00  554.220759  554.628767  550.100588  552.787659
# ...                               ...         ...         ...         ...
# 2026-06-26 00:00:00-04:00  707.130005  715.559998  702.809998  706.520020
# 2026-06-29 00:00:00-04:00  713.989990  724.580017  705.169983  724.080017
# 2026-06-30 00:00:00-04:00  724.179993  737.619995  723.909973  736.400024
# 2026-07-01 00:00:00-04:00  729.190002  731.919983  724.599976  725.169983
# 2026-07-02 00:00:00-04:00  725.580017  730.830017  707.559998  712.599976
#
# ...

# %%
ticker.funds_data.top_holdings
# Out:
#                               Name  Holding Percent
# Symbol
# NVDA                   NVIDIA Corp         0.081576
# AAPL                     Apple Inc         0.072842
# MSFT                Microsoft Corp         0.053153
# MU           Micron Technology Inc         0.047964
# AMZN                Amazon.com Inc         0.046192
# AMD     Advanced Micro Devices Inc         0.036929
# GOOGL         Alphabet Inc Class A         0.035201
# TSLA                     Tesla Inc         0.034580
# AVGO                  Broadcom Inc         0.033677
# GOOG          Alphabet Inc Class C         0.032549

# %%
yf.Market("ASIA").summary
# Out:
# ASIA: Yahoo markettime endpoint does not support market='ASIA'; status data unavailable.
# {'SHH': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 867807000000,
#   'priceHint': 2,
#   'regularMarketChange': 14.739502,
#   'regularMarketChangePercent': 0.36584398,
#   'regularMarketTime': 1783062029,
#   'regularMarketPrice': 4043.6433,
#   'regularMarketPreviousClose': 4112.44,
#   'exchange': 'SHH',
#   'market': 'cn_market',
#   'fullExchangeName': 'Shanghai',
#   'marketState': 'POSTPOST',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 15,
#   'exchangeTimezoneName': 'Asia/Shanghai',
#   'exchangeTimezoneShortName': 'CST',
#   'gmtOffSetMilliseconds': 28800000,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
# ...
