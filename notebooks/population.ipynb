# %%
import wbgapi as wb

# %%
population = wb.data.DataFrame('SP.POP.TOTL', 'IND').transpose()
print("Total Population")
print(population)
# Out:
# economy           IND
# YR1960   4.359903e+08
# YR1961   4.465647e+08
# YR1962   4.572831e+08
# YR1963   4.681386e+08
# YR1964   4.792296e+08
# ...               ...
# YR2021   1.414204e+09
# YR2022   1.425423e+09
# YR2023   1.438070e+09
# YR2024   1.450936e+09
# YR2025   1.463866e+09
#
# [66 rows x 1 columns]

# %%
urban_population = wb.data.DataFrame('SP.URB.TOTL', ['IND','PAK']).transpose()
print("Urban Population")
print(urban_population)
# Out:
# Urban Population
# economy          IND          PAK
# YR1960    78151300.0   10193038.0
# YR1961    80488867.0   10619283.0
# YR1962    82967482.0   11044230.0
# YR1963    85593783.0   11475929.0
# YR1964    88384509.0   11917942.0
# ...              ...          ...
# YR2021   487087908.0   90841927.0
# YR2022   495413925.0   93517801.0
# YR2023   504297814.0   96079231.0
# YR2024   513325082.0   98430767.0
# YR2025   522441248.0  100877063.0
#
# [66 rows x 2 columns]

# %%
adult_literacy = wb.data.DataFrame('SE.ADT.LITR.ZS', ['IND','PAK']).transpose()
print("Adult Literacy")
print(adult_literacy)
# Out:
# Adult Literacy
# economy        IND        PAK
# YR1960         NaN        NaN
# YR1961         NaN        NaN
# YR1962         NaN        NaN
# YR1963         NaN        NaN
# YR1964         NaN        NaN
# ...            ...        ...
# YR2021   76.059662  58.860001
# YR2022   76.320000        NaN
# YR2023   81.699997        NaN
# YR2024   78.162533        NaN
# YR2025         NaN        NaN
#
# [66 rows x 2 columns]
